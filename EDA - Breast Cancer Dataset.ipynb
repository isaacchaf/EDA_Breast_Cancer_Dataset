# %% [markdown]
# ## EDA - Breast Cancer Dataset

# %%
# Library Import
from sklearn import datasets
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Breast cancer datase
breast_cancer = datasets.load_breast_cancer()

# Pyhton Function
def type_cancer(value):
    cancer = breast_cancer.target_names[value]
    return cancer

# %%
# Dataframe
cancer_data = pd.DataFrame(breast_cancer.data, columns = breast_cancer.feature_names)
cancer_data["TypeCancer"] = breast_cancer.target
# Editing column names
cancer_data.columns = cancer_data.columns.str.replace(" ", "")
cancer_data.TypeCancer = cancer_data.TypeCancer.apply(type_cancer)
cancer_data.head()
# Out:
#    meanradius  meantexture  meanperimeter  meanarea  meansmoothness  \
# 0       17.99        10.38         122.80    1001.0         0.11840
# 1       20.57        17.77         132.90    1326.0         0.08474
# 2       19.69        21.25         130.00    1203.0         0.10960
# 3       11.42        20.38          77.58     386.1         0.14250
# 4       20.29        14.34         135.10    1297.0         0.10030
#
#    meancompactness  meanconcavity  meanconcavepoints  meansymmetry  \
# 0          0.27760         0.3001            0.14710        0.2419
# 1          0.07864         0.0869            0.07017        0.1812
# 2          0.15990         0.1974            0.12790        0.2069
# 3          0.28390         0.2414            0.10520        0.2597
# 4          0.13280         0.1980            0.10430        0.1809
#
#    meanfractaldimension  ...  worsttexture  worstperimeter  worstarea  \
# 0               0.07871  ...         17.33          184.60     2019.0
# ...

# %% [markdown]
# # Univariate Analysis

# %%
# Data Size
cancer_shape = cancer_data.shape
print("Number of Observations: ", cancer_shape[0])
print("Number of Columns: ", cancer_shape[1])
# Out:
# Number of Observations:  569
# Number of Columns:  31

# %%
# Data Characteristics
cancer_data.describe().T
# Out:
#                        count        mean         std         min         25%  \
# meanradius             569.0   14.127292    3.524049    6.981000   11.700000
# meantexture            569.0   19.289649    4.301036    9.710000   16.170000
# meanperimeter          569.0   91.969033   24.298981   43.790000   75.170000
# meanarea               569.0  654.889104  351.914129  143.500000  420.300000
# meansmoothness         569.0    0.096360    0.014064    0.052630    0.086370
# meancompactness        569.0    0.104341    0.052813    0.019380    0.064920
# meanconcavity          569.0    0.088799    0.079720    0.000000    0.029560
# meanconcavepoints      569.0    0.048919    0.038803    0.000000    0.020310
# meansymmetry           569.0    0.181162    0.027414    0.106000    0.161900
# meanfractaldimension   569.0    0.062798    0.007060    0.049960    0.057700
# radiuserror            569.0    0.405172    0.277313    0.111500    0.232400
# ...

# %%
# Data (Storage) Type
cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# meanradius               569 non-null float64
# meantexture              569 non-null float64
# meanperimeter            569 non-null float64
# meanarea                 569 non-null float64
# meansmoothness           569 non-null float64
# meancompactness          569 non-null float64
# meanconcavity            569 non-null float64
# meanconcavepoints        569 non-null float64
# meansymmetry             569 non-null float64
# meanfractaldimension     569 non-null float64
# radiuserror              569 non-null float64
# textureerror             569 non-null float64
# perimetererror           569 non-null float64
# areaerror                569 non-null float64
# smoothnesserror          569 non-null float64
# compactnesserror         569 non-null float64
# concavityerror           569 non-null float64
# concavepointserror       569 non-null float64
# ...

# %%
# Null values 
cancer_data.isnull().sum()
# Out:
# meanradius               0
# meantexture              0
# meanperimeter            0
# meanarea                 0
# meansmoothness           0
# meancompactness          0
# meanconcavity            0
# meanconcavepoints        0
# meansymmetry             0
# meanfractaldimension     0
# radiuserror              0
# textureerror             0
# perimetererror           0
# areaerror                0
# smoothnesserror          0
# compactnesserror         0
# concavityerror           0
# concavepointserror       0
# symmetryerror            0
# fractaldimensionerror    0
# worstradius              0
# worsttexture             0
# worstperimeter           0
# worstarea                0
# worstsmoothness          0
# worstcompactness         0
# worstconcavity           0
# worstconcavepoints       0
# worstsymmetry            0
# worstfractaldimension    0
# TypeCancer               0
# dtype: int64

# %%
# Variable Balance 
cancer_data.TypeCancer.value_counts()
# Out:
# benign       357
# malignant    212
# Name: TypeCancer, dtype: int64

# %%
# Separating the datasets
mean_variables = cancer_data.filter(regex='^mean',axis=1)
mean_variables['Type'] = cancer_data['TypeCancer'].copy()

error_variables = cancer_data.filter('error$', axis=1)

worst_variables = cancer_data.filter(regex='^worst',axis=1)

mean_variables
# Out:
# /Users/marcochavezf/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      meanradius  meantexture  meanperimeter  meanarea  meansmoothness  \
# 0        17.990        10.38         122.80    1001.0         0.11840
# 1        20.570        17.77         132.90    1326.0         0.08474
# 2        19.690        21.25         130.00    1203.0         0.10960
# 3        11.420        20.38          77.58     386.1         0.14250
# 4        20.290        14.34         135.10    1297.0         0.10030
# 5        12.450        15.70          82.57     477.1         0.12780
# ...

# %%
plt.figure(figsize = (100,100))
cancer_data.hist()
plt.suptitle("Histograms")
plt.show()

cancer_data.boxplot()
plt.title("Boxplot")
plt.show()

# %%
for column in cancer_data.columns[:30]:
    g = sns.FacetGrid(cancer_data, hue = "TypeCancer", height = 4)
    g = g.map(sns.distplot, column)
    g = g.add_legend()
    plt.show()

# %%
# Variable Means 
cancer_data.groupby(by = 'TypeCancer').mean().T
# Out:
# TypeCancer                 benign    malignant
# meanradius              12.146524    17.462830
# meantexture             17.914762    21.604906
# meanperimeter           78.075406   115.365377
# meanarea               462.790196   978.376415
# meansmoothness           0.092478     0.102898
# meancompactness          0.080085     0.145188
# meanconcavity            0.046058     0.160775
# meanconcavepoints        0.025717     0.087990
# meansymmetry             0.174186     0.192909
# meanfractaldimension     0.062867     0.062680
# radiuserror              0.284082     0.609083
# textureerror             1.220380     1.210915
# perimetererror           2.000321     4.323929
# areaerror               21.135148    72.672406
# smoothnesserror          0.007196     0.006780
# compactnesserror         0.021438     0.032281
# concavityerror           0.025997     0.041824
# concavepointserror       0.009858     0.015060
# symmetryerror            0.020584     0.020472
# ...

# %%
cancer_data.groupby(by = 'TypeCancer').mean().plot(kind = "bar")
plt.title("Dataset Variables")
plt.ylabel("Features Mean")
plt.grid(True)
plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))

# %% [markdown]
# # Multivariate Analysis

# %%
# Correlation matrix
correlation_matrix = cancer_data.corr()

# %%
# Heatmap
sns.heatmap(correlation_matrix, annot = True, cmap ='RdBu')
plt.show()
